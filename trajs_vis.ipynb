# %%
from tools import tools_file
from tools import tools_plot

# %%
# 可视化 noise
ARROW_SIZE = 0.02
ARROW_INTV = 0.01

PKL_PATH = "Data_Processed/VIJIAYAN/circular_yz_0_05_mps_standing.pkl"
data_tf = tools_file.pkl_to_tf(PKL_PATH)

tools_plot.plot_3d(data_tf[0]["tf"], ARROW_SIZE, ARROW_INTV, "normal")
